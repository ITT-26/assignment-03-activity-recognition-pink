# %%
import glob
import os
import matplotlib
from matplotlib import pyplot as plt
from sklearn import svm # scikit-learn
import seaborn as sns # for nice visualizations
import pandas as pd # for loading the data from csv
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import svm

# %%
dfs = []
for path in glob.glob('shared_data/**/*.csv', recursive=True):
    parts = os.path.basename(path).replace('.csv', "").split('-')
    df = pd.read_csv(path)
    df['person']    = parts[0]
    df['activity']  = parts[1]
    df['frequency'] = parts[2]
    df['placement'] = parts[3]
    df['trial']     = int(parts[4])
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)
print(df.shape)
df.head()
# Out:
# (510243, 13)
#    id     timestamp     acc_x     acc_y     acc_z    gyro_x    gyro_y  \
# 0   1  1.778591e+09  3.127838 -3.462684 -0.724850  1.678857 -2.765959
# 1   2  1.778591e+09  3.059746 -3.413873 -1.105091  1.678857 -2.765959
# 2   3  1.778591e+09  1.407966 -3.197394 -1.922439  2.915629 -0.991229
# 3   4  1.778591e+09 -0.186704 -2.953337 -1.360131  1.057808 -1.102549
# 4   5  1.778591e+09 -0.186704 -2.953337 -1.360131  1.057808 -1.102549
#
#      gyro_z  person      activity frequency placement  trial
# 0 -5.057343  daniel  jumpingjacks     100Hz      hand      1
# 1 -5.057343  daniel  jumpingjacks     100Hz      hand      1
# 2 -7.732222  daniel  jumpingjacks     100Hz      hand      1
# 3 -8.827314  daniel  jumpingjacks     100Hz      hand      1
# 4 -8.827314  daniel  jumpingjacks     100Hz      hand      1

# %% [markdown]
# ## Data Cleanup

# %%
df['person'] = df['person'].str.lower()
df['activity'] = df['activity'].str.lower()
df['placement'] = df['placement'].str.lower()

# %%
df['person'].value_counts()
# Out:
# person
# ferdi         48040
# vanessa       48040
# maximilian    48005
# marcel        48002
# patrick       48000
# lennart       48000
# martina       47998
# felix         47984
# georg         47949
# thu           41771
# daniel        35454
# susi           1000
# Name: count, dtype: int64

# %%
df = df[df['person'] != 'susi']  # drop susi

# %%
df.groupby('person')['gyro_x'].max()
# Out:
# person
# daniel           9.540508
# felix         1156.370000
# ferdi           19.591824
# georg           11.147519
# lennart        399.960000
# marcel          14.213613
# martina          0.000000
# maximilian    1262.820000
# patrick          9.649067
# thu             12.005173
# vanessa         12.594820
# Name: gyro_x, dtype: float64

# %%
m5stack = ['felix', 'lennart', 'maximilian']
df.loc[df['person'].isin(m5stack), ['gyro_x', 'gyro_y', 'gyro_z']] /= 180/np.pi

# %%
df.groupby('person')['gyro_x'].apply(lambda x: x.abs().max())
# Out:
# person
# daniel        10.488594
# felix         25.926342
# ferdi         21.292930
# georg         13.684593
# lennart        9.290213
# marcel        14.213613
# martina        0.000000
# maximilian    34.906585
# patrick        9.964579
# thu           18.177504
# vanessa       12.594820
# Name: gyro_x, dtype: float64

# %%
df['acc_mag'] = np.sqrt(df['acc_x']**2 + df['acc_y']**2 + df['acc_z']**2)
df['sample_idx'] = df.groupby(['person', 'activity', 'frequency', 'placement', 'trial']).cumcount()

mean_by_freq = df.groupby(['frequency', 'sample_idx'])['acc_mag'].mean().reset_index()

for freq, group in mean_by_freq.groupby('frequency'):
    plt.plot(group['sample_idx'][:200], group['acc_mag'][:200], label=freq)

plt.xlabel('Sample index n')
plt.ylabel('Mean acc magnitude')
plt.title('Mean accelerometer magnitude across all recordings')
plt.legend()
plt.show()

# %% [markdown]
# # Training

# %%
COLS = ['acc_x', 'acc_y', 'acc_z', 'gyro_x', 'gyro_y', 'gyro_z']
WIN, STEP = 51, 25  # 2.56s at 20Hz

rows = []
for (person, activity, placement, trial), g in df[df['frequency']=='20Hz'].groupby(['person','activity','placement','trial']):
    g = g.reset_index(drop=True)
    for s in range(0, len(g) - WIN + 1, STEP):
        w = g.iloc[s:s+WIN][COLS].values.T
        rows.append([*w.mean(1), *w.std(1), *np.ptp(w, axis=1),
                     *[(np.diff(np.sign(r)) != 0).sum()/len(r) for r in w],
                     activity, person])

windows = pd.DataFrame(rows)
feat_names = [f'{f}_{c}' for f in ['mean','std','range','zcr'] for c in COLS]
windows.columns = feat_names + ['activity', 'person']
print(windows.shape)
# Out:
# (2763, 26)

# %%
windows.head()
# Out:
#    mean_acc_x  mean_acc_y  mean_acc_z  mean_gyro_x  mean_gyro_y  mean_gyro_z  \
# 0   -2.246222   -1.452279    0.385012     0.022026    -1.001902     0.275371
# 1   -2.221050   -1.603973    0.143936     0.327224    -1.257294    -0.840943
# 2   -2.094566   -1.714770    0.095010     0.265136    -1.246464     0.458837
# 3   -2.304561   -1.050351   -0.106256    -0.041096    -0.816807    -0.355078
# 4   -1.737970   -1.116433   -0.269970     0.231643    -0.834039    -0.880525
#
#    std_acc_x  std_acc_y  std_acc_z  std_gyro_x  ...  range_gyro_y  \
# 0   2.502095   1.450343   0.818059    2.951993  ...     10.713364
# 1   2.686499   1.524854   0.753553    2.529411  ...      9.381784
# 2   2.876824   1.668643   0.846473    2.095983  ...      8.046475
# 3   2.782710   1.782010   0.911103    2.043521  ...      7.116499
# 4   2.771685   1.595719   0.807605    1.996886  ...      6.845389
#
#    range_gyro_z  zcr_acc_x  zcr_acc_y  zcr_acc_z  zcr_gyro_x  zcr_gyro_y  \
# ...

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
test_persons = ['georg', 'patrick']  # hold out 2 people
train = windows[~windows['person'].isin(test_persons)]
test  = windows[ windows['person'].isin(test_persons)]

X_train = train[feat_names].astype(float)
y_train = train['activity']
X_test  = test[feat_names].astype(float)
y_test  = test['activity']

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# 0.7458333333333333

# %%
for kernel in ['linear', 'rbf', 'poly', 'sigmoid']:
    clf = svm.SVC(kernel=kernel)
    clf.fit(X_train, y_train)
    print(kernel, clf.score(X_test, y_test))
# Out:
# linear 0.6104166666666667
# rbf 0.7458333333333333
# poly 0.68125
# sigmoid 0.5583333333333333

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay(confusion_matrix(y_test, clf.predict(X_test)), display_labels=clf.classes_).plot()

# %%
print(windows['activity'].unique())
# Out:
# ['jumpingjacks' 'lifting' 'rowing' 'running']
